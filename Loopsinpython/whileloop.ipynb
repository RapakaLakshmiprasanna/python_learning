# %% [markdown]
# while loop is used in python when the temination point is not well known... example : number guessing game

# %%
number = int(input("enter a number"))
i=1
while i <11:
    print(number"X" i = i*number)
    i+=1
# Out:
#   Cell In[2], line 4
#     print(number"X" i = i*number)
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import random
random.randint(1,100)
# Out:
# 7
